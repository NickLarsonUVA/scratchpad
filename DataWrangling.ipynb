# %% [markdown]
# <a href="https://colab.research.google.com/github/NickLarsonUVA/scratchpad/blob/main/DataWrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/NickLarsonUVA/scratchpad
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 39 (delta 5), reused 0 (delta 0), pack-reused 30 (from 1)
# Receiving objects: 100% (39/39), 57.90 KiB | 9.65 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
import urllib.request
import os
import zipfile
import os

def download_data(force=False):
    """Download and extract course data from Zenodo."""

    zip_path = 'data.zip'
    data_dir = './data'

    if not os.path.exists(zip_path) or force:
        print("Downloading course data...")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/18235955/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")

    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")

    return data_dir


if __name__ == "__main__":
    download_data()
# Out:
# Downloading course data...

# %%
import pandas as pd
df = pd.read_csv("/content/data/sharks.csv", encoding="latin1")

# %%
df.dtypes

# %%
df.shape

# %%
df.tail()

# %%
df['Area'].unique()

# %%
df['Area'].value_counts()

# %%
df['Year'].hist()

# %%
df['Year'].describe()

# %%
df['Year_na'] = df['Year'].isna()

# %%
df['Year_na'].describe() #?

# %%
df['Year'].unique()

# %%
# no commas, pretty clean, except for nan, in numeric values
#df['Year'].str.replace('.0','')  # already a numeric value so can't use this as it works for strings
pd.to_numeric(df['Year'],errors='coerce')

# %%
df['Area'].str.replace(',','')
